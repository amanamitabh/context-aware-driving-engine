# %%
import ultralytics
from ultralytics import YOLO

# %%
ultralytics.checks()
# Out:
# Ultralytics 8.4.14  Python-3.10.4 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1660 Ti with Max-Q Design, 6144MiB)
# Setup complete  (8 CPUs, 13.9 GB RAM, 690.5/799.7 GB disk)

# %%
# Load the YOLOv8 nano model
model = YOLO("yolov8n")

# %% [markdown]
# MODEL TRAINING

# %%
results = model.train(
    data="traffic_signv3/data.yaml",
    epochs=30,
    batch=16,
    name="yolov8n",
)
# Out:
# Ultralytics 8.4.14  Python-3.10.4 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1660 Ti with Max-Q Design, 6144MiB)
# ...
